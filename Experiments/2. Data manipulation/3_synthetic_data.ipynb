# %%
# How changing the dataset sample size effects the calibration methods
# Fix training dataset size and change the calib set samples - best method is one that gets max calib with least data

# imports
import sys
import numpy as np
import pandas as pd
sys.path.append('../../') # to access the files in higher directories
sys.path.append('../') # to access the files in higher directories
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import core_exp as cx
import core_calib as cal
import core_tools as ct

import warnings
from sklearn.exceptions import DataConversionWarning

# Ignore all warnings from scikit-learn
warnings.filterwarnings("ignore", module="sklearn")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
# Add more categories if needed

# %%
n_s_data = 100

params = {
    # exp
    "seed": 0,
    "runs": 1,
    "exp_name": ct.generate_readable_short_id("synthetic_run100"), # 
    "path": "../../",
    "split": "random_split", #CV, random_split
    "test_split": 0.2,
    "calib_split": 0.2,

    "plot_data": False,
    "plot": False,
    "n_jobs": 1,

    "calib_methods": [
                    #   "RF_d",
                      "RF_opt", 
                      "Platt", "ISO", "Beta", "VA",
                      "CT", "PPA",
                      "Shaker",
                      ],

    "calib_method_colors": {
        # "RF_d": "blue", 
        "RF_opt": "orange", 
        "Platt": "Brown", 
        "ISO": "purple", 
        "Beta": "magenta", 
        "VA": "gray",
        "CT": "slategray",
        "PPA": "olive", 
        "Shaker": "gold",
    },


    "metrics": ["acc", "brier", "ece", "logloss", "time", "tce_mse"],

    # calib param   
    "bin_strategy": "uniform",
    "ece_bins": 20,

    # RF hyper opt
    "hyper_opt": True,
    "opt_cv":5, 
    "opt_n_iter":50,
    "opt_top_K": 5,
    "search_space": {
                    "n_estimators": [10],
                    "max_depth":  np.arange(2, 100).tolist() + [None], # [None, 5, 10, 15, 20, 30, 50], #
                    "criterion": ["gini", "entropy"],
                    "max_features": ['sqrt', 'log2', None],
                    "min_samples_split": np.arange(2, 11).tolist(),
                    "min_samples_leaf":  np.arange(1, 11).tolist(),
                    'class_weight': [None, 'balanced', 'balanced_subsample'],  # Weight for each class
                    "oob_score": [False],
                    "laplace": [0,1]
                    },
    
    "oob": False,
    "laplace":0, # if set to 1, OOB must be false
    "curt_v": np.arange(1, 100).tolist(),

    "exp_key": "data_name",
    "n_features": 10,
    "data_size": 5000,
    
    "exp_values": [f"synthetic_nn{i}" for i in range(1, n_s_data + 1)]
}

ct.save_params(params)

# %%
calib_results_dict, data_list = cx.run_exp(params["exp_key"], params["exp_values"], params)
ct.save_results(calib_results_dict, params['exp_name'])
# Out:
# exp_param synthetic_nn1 done
# exp_param synthetic_nn2 done
# exp_param synthetic_nn3 done
# exp_param synthetic_nn4 done
# exp_param synthetic_nn5 done
# exp_param synthetic_nn6 done
# exp_param synthetic_nn7 done
# exp_param synthetic_nn8 done
# exp_param synthetic_nn9 done
# exp_param synthetic_nn10 done
# exp_param synthetic_nn11 done
# exp_param synthetic_nn12 done
# exp_param synthetic_nn13 done
# exp_param synthetic_nn14 done
# exp_param synthetic_nn15 done
# exp_param synthetic_nn16 done
# exp_param synthetic_nn17 done
# exp_param synthetic_nn18 done
# exp_param synthetic_nn19 done
# exp_param synthetic_nn20 done
# exp_param synthetic_nn21 done
# exp_param synthetic_nn22 done
# exp_param synthetic_nn23 done
# exp_param synthetic_nn24 done
# exp_param synthetic_nn25 done
# exp_param synthetic_nn26 done
# exp_param synthetic_nn27 done
# exp_param synthetic_nn28 done
# exp_param synthetic_nn29 done
# exp_param synthetic_nn30 done
# exp_param synthetic_nn31 done
# exp_param synthetic_nn32 done
# exp_param synthetic_nn33 done
# exp_param synthetic_nn34 done
# exp_param synthetic_nn35 done
# exp_param synthetic_nn36 done
# exp_param synthetic_nn37 done
# exp_param synthetic_nn38 done
# exp_param synthetic_nn39 done
# exp_param synthetic_nn40 done
# exp_param synthetic_nn41 done
# exp_param synthetic_nn42 done
# exp_param synthetic_nn43 done
# exp_param synthetic_nn44 done
# exp_param synthetic_nn45 done
# exp_param synthetic_nn46 done
# exp_param synthetic_nn47 done
# exp_param synthetic_nn48 done
# exp_param synthetic_nn49 done
# exp_param synthetic_nn50 done
# exp_param synthetic_nn51 done
# exp_param synthetic_nn52 done
# exp_param synthetic_nn53 done
# exp_param synthetic_nn54 done
# exp_param synthetic_nn55 done
# exp_param synthetic_nn56 done
# exp_param synthetic_nn57 done
# exp_param synthetic_nn58 done
# exp_param synthetic_nn59 done
# exp_param synthetic_nn60 done
# exp_param synthetic_nn61 done
# exp_param synthetic_nn62 done
# exp_param synthetic_nn63 done
# exp_param synthetic_nn64 done
# exp_param synthetic_nn65 done
# exp_param synthetic_nn66 done
# exp_param synthetic_nn67 done
# exp_param synthetic_nn68 done
# exp_param synthetic_nn69 done
# exp_param synthetic_nn70 done
# exp_param synthetic_nn71 done
# exp_param synthetic_nn72 done
# exp_param synthetic_nn73 done
# exp_param synthetic_nn74 done
# exp_param synthetic_nn75 done
# exp_param synthetic_nn76 done
# exp_param synthetic_nn77 done
# exp_param synthetic_nn78 done
# exp_param synthetic_nn79 done
# exp_param synthetic_nn80 done
# exp_param synthetic_nn81 done
# exp_param synthetic_nn82 done
# exp_param synthetic_nn83 done
# exp_param synthetic_nn84 done
# exp_param synthetic_nn85 done
# exp_param synthetic_nn86 done
# exp_param synthetic_nn87 done
# exp_param synthetic_nn88 done
# exp_param synthetic_nn89 done
# exp_param synthetic_nn90 done
# exp_param synthetic_nn91 done
# exp_param synthetic_nn92 done
# exp_param synthetic_nn93 done
# exp_param synthetic_nn94 done
# exp_param synthetic_nn95 done
# exp_param synthetic_nn96 done
# exp_param synthetic_nn97 done
# exp_param synthetic_nn98 done
# exp_param synthetic_nn99 done
# exp_param synthetic_nn100 done

# %%
tables = cal.mean_and_ranking_table(calib_results_dict, 
                                    params["metrics"], 
                                    params["calib_methods"], 
                                    data_list, 
                                    mean_and_rank=True, 
                                    std=True)
ct.save_metrics_to_csv(tables, params["metrics"], params['exp_name'])

# %%
ct.res_statistics(tables, params["metrics"], f"results/{params['exp_name']}", colors=params["calib_method_colors"])
# Out:
# metric acc
# Friedman Test Statistic: 224.49650349650346
# P-value: 7.324363569194864e-45
# The differences between groups are significant.
# metric brier
# Friedman Test Statistic: 459.8291984732825
# P-value: 3.438949559731338e-95
# The differences between groups are significant.
# metric ece
# Friedman Test Statistic: 137.51585976627732
# P-value: 1.6841715114359248e-26
# The differences between groups are significant.
# metric logloss
# Friedman Test Statistic: 483.0016700465231
# P-value: 3.6119416667434124e-100
# The differences between groups are significant.
# metric time
# Friedman Test Statistic: 590.3433333333337
# P-value: 2.923249007042103e-123
# The differences between groups are significant.
# metric tce_mse
# Friedman Test Statistic: 548.3361184053474
# P-value: 3.2192476316600758e-114
# The differences between groups are significant.

# %%
ct.save_metrics_to_latex(tables, params["metrics"], params['exp_name'])

# %%
calib_results_dict.keys()
# Out:
# dict_keys(['synthetic_nn1_RF_opt_runtime', 'synthetic_nn1_Platt_runtime', 'synthetic_nn1_ISO_runtime', 'synthetic_nn1_PPA_runtime', 'synthetic_nn1_Shaker_runtime', 'synthetic_nn1_VA_runtime', 'synthetic_nn1_Beta_runtime', 'synthetic_nn1_CT_runtime', 'synthetic_nn1_RF_opt_time', 'synthetic_nn1_Platt_time', 'synthetic_nn1_ISO_time', 'synthetic_nn1_Beta_time', 'synthetic_nn1_VA_time', 'synthetic_nn1_CT_time', 'synthetic_nn1_PPA_time', 'synthetic_nn1_Shaker_time', 'synthetic_nn1_RF_opt_acc', 'synthetic_nn1_Platt_acc', 'synthetic_nn1_ISO_acc', 'synthetic_nn1_Beta_acc', 'synthetic_nn1_VA_acc', 'synthetic_nn1_CT_acc', 'synthetic_nn1_PPA_acc', 'synthetic_nn1_Shaker_acc', 'synthetic_nn1_RF_opt_ece', 'synthetic_nn1_Platt_ece', 'synthetic_nn1_ISO_ece', 'synthetic_nn1_Beta_ece', 'synthetic_nn1_VA_ece', 'synthetic_nn1_CT_ece', 'synthetic_nn1_PPA_ece', 'synthetic_nn1_Shaker_ece', 'synthetic_nn1_RF_opt_brier', 'synthetic_nn1_Platt_brier', 'synthetic_nn1_ISO_brier', 'synthetic_nn1_Beta_brier', 'synthetic_nn1_VA_brier', 'synthetic_nn1_CT_brier', 'synthetic_nn1_PPA_brier', 'synthetic_nn1_Shaker_brier', 'synthetic_nn1_RF_opt_logloss', 'synthetic_nn1_Platt_logloss', 'synthetic_nn1_ISO_logloss', 'synthetic_nn1_Beta_logloss', 'synthetic_nn1_VA_logloss', 'synthetic_nn1_CT_logloss', 'synthetic_nn1_PPA_logloss', 'synthetic_nn1_Shaker_logloss', 'synthetic_nn1_RF_opt_tce_mse', 'synthetic_nn1_Platt_tce_mse', 'synthetic_nn1_ISO_tce_mse', 'synthetic_nn1_Beta_tce_mse', 'synthetic_nn1_VA_tce_mse', 'synthetic_nn1_CT_tce_mse', 'synthetic_nn1_PPA_tce_mse', 'synthetic_nn1_Shaker_tce_mse', 'synthetic_nn2_RF_opt_runtime', 'synthetic_nn2_Platt_runtime', 'synthetic_nn2_ISO_runtime', 'synthetic_nn2_PPA_runtime', 'synthetic_nn2_Shaker_runtime', 'synthetic_nn2_VA_runtime', 'synthetic_nn2_Beta_runtime', 'synthetic_nn2_CT_runtime', 'synthetic_nn2_RF_opt_time', 'synthetic_nn2_Platt_time', 'synthetic_nn2_ISO_time', 'synthetic_nn2_Beta_time', 'synthetic_nn2_VA_time', 'synthetic_nn2_CT_time', 'synthetic_nn2_PPA_time', 'synthetic_nn2_Shaker_time', 'synthetic_nn2_RF_opt_acc', 'synthetic_nn2_Platt_acc', 'synthetic_nn2_ISO_acc', 'synthetic_nn2_Beta_acc', 'synthetic_nn2_VA_acc', 'synthetic_nn2_CT_acc', 'synthetic_nn2_PPA_acc', 'synthetic_nn2_Shaker_acc', 'synthetic_nn2_RF_opt_ece', 'synthetic_nn2_Platt_ece', 'synthetic_nn2_ISO_ece', 'synthetic_nn2_Beta_ece', 'synthetic_nn2_VA_ece', 'synthetic_nn2_CT_ece', 'synthetic_nn2_PPA_ece', 'synthetic_nn2_Shaker_ece', 'synthetic_nn2_RF_opt_brier', 'synthetic_nn2_Platt_brier', 'synthetic_nn2_ISO_brier', 'synthetic_nn2_Beta_brier', 'synthetic_nn2_VA_brier', 'synthetic_nn2_CT_brier', 'synthetic_nn2_PPA_brier', 'synthetic_nn2_Shaker_brier', 'synthetic_nn2_RF_opt_logloss', 'synthetic_nn2_Platt_logloss', 'synthetic_nn2_ISO_logloss', 'synthetic_nn2_Beta_logloss', 'synthetic_nn2_VA_logloss', 'synthetic_nn2_CT_logloss', 'synthetic_nn2_PPA_logloss', 'synthetic_nn2_Shaker_logloss', 'synthetic_nn2_RF_opt_tce_mse', 'synthetic_nn2_Platt_tce_mse', 'synthetic_nn2_ISO_tce_mse', 'synthetic_nn2_Beta_tce_mse', 'synthetic_nn2_VA_tce_mse', 'synthetic_nn2_CT_tce_mse', 'synthetic_nn2_PPA_tce_mse', 'synthetic_nn2_Shaker_tce_mse', 'synthetic_nn3_RF_opt_runtime', 'synthetic_nn3_Platt_runtime', 'synthetic_nn3_ISO_runtime', 'synthetic_nn3_PPA_runtime', 'synthetic_nn3_Shaker_runtime', 'synthetic_nn3_VA_runtime', 'synthetic_nn3_Beta_runtime', 'synthetic_nn3_CT_runtime', 'synthetic_nn3_RF_opt_time', 'synthetic_nn3_Platt_time', 'synthetic_nn3_ISO_time', 'synthetic_nn3_Beta_time', 'synthetic_nn3_VA_time', 'synthetic_nn3_CT_time', 'synthetic_nn3_PPA_time', 'synthetic_nn3_Shaker_time', 'synthetic_nn3_RF_opt_acc', 'synthetic_nn3_Platt_acc', 'synthetic_nn3_ISO_acc', 'synthetic_nn3_Beta_acc', 'synthetic_nn3_VA_acc', 'synthetic_nn3_CT_acc', 'synthetic_nn3_PPA_acc', 'synthetic_nn3_Shaker_acc', 'synthetic_nn3_RF_opt_ece', 'synthetic_nn3_Platt_ece', 'synthetic_nn3_ISO_ece', 'synthetic_nn3_Beta_ece', 'synthetic_nn3_VA_ece', 'synthetic_nn3_CT_ece', 'synthetic_nn3_PPA_ece', 'synthetic_ ...
